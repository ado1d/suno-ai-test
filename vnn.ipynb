# %% [markdown]
# <a href="https://colab.research.google.com/github/ado1d/suno-ai-test/blob/main/vnn.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# !nvidia-smi
# Out:
# Tue Aug 18 18:58:25 2026
# +-----------------------------------------------------------------------------------------+
# | NVIDIA-SMI 580.82.07              Driver Version: 580.82.07      CUDA Version: 13.0     |
# +-----------------------------------------+------------------------+----------------------+
# | GPU  Name                 Persistence-M | Bus-Id          Disp.A | Volatile Uncorr. ECC |
# | Fan  Temp   Perf          Pwr:Usage/Cap |           Memory-Usage | GPU-Util  Compute M. |
# |                                         |                        |               MIG M. |
# |=========================================+========================+======================|
# |   0  Tesla T4                       Off |   00000000:00:04.0 Off |                    0 |
# | N/A   43C    P8             11W /   70W |       0MiB /  15360MiB |      0%      Default |
# |                                         |                        |                  N/A |
# ...

# %%
# %%bash
# # Node 20 (for frontend build)
# curl -fsSL https://deb.nodesource.com/setup_20.x | bash -
# apt-get install -y nodejs
# node -v && npm -v
#
# # Ollama (free local LLM for lyrics)
# curl -fsSL https://ollama.com/install.sh | sh
#
# # System audio libs (just in case)
# apt-get install -y ffmpeg libsndfile1
# Out:
# 2026-08-18 18:59:04 - Installing pre-requisites
# Hit:1 https://cli.github.com/packages stable InRelease
# Get:2 https://cloud.r-project.org/bin/linux/ubuntu jammy-cran40/ InRelease [3,632 B]
# Get:3 https://developer.download.nvidia.com/compute/cuda/repos/ubuntu2204/x86_64  InRelease [1,578 B]
# Get:4 http://security.ubuntu.com/ubuntu jammy-security InRelease [129 kB]
# Get:5 https://cloud.r-project.org/bin/linux/ubuntu jammy-cran40/ Packages [108 kB]
# Get:6 https://developer.download.nvidia.com/compute/cuda/repos/ubuntu2204/x86_64  Packages [2,908 kB]
# Hit:7 http://archive.ubuntu.com/ubuntu jammy InRelease
# Get:8 http://archive.ubuntu.com/ubuntu jammy-updates InRelease [128 kB]
# Get:9 http://security.ubuntu.com/ubuntu jammy-security/universe amd64 Packages [1,314 kB]
# Get:10 http://security.ubuntu.com/ubuntu jammy-security/main amd64 Packages [4,202 kB]
# Get:11 https://r2u.stat.illinois.edu/ubuntu jammy InRelease [6,555 B]
# ...

# %%
# %%bash
# # Run Ollama server in background, listening on localhost:11434
# nohup ollama serve > /tmp/ollama.log 2>&1 &
# sleep 5
#
# # Pull a small, fast model for lyrics generation (~2 GB)
# ollama pull llama3.2
# Out:
# bash: line 6: ollama: command not found
# ---------------------------------------------------------------------------
# CalledProcessError                        Traceback (most recent call last)
# /tmp/ipykernel_2641/3615157812.py in <cell line: 0>()
# ----> 1 get_ipython().run_cell_magic('bash', '', '# Run Ollama server in background, listening on localhost:11434\nnohup ollama serve > /tmp/ollama.log 2>&1 &\nsleep 5\n\n# Pull a small, fast model for lyrics generation (~2 GB)\nollama pull llama3.2\n')
#
# /usr/local/lib/python3.12/dist-packages/google/colab/_shell.py in run_cell_magic(self, magic_name, line, cell)
#     221     if line and not cell:
#     222       cell = ' '
# --> 223     return super().run_cell_magic(magic_name, line, cell)
#     224
#     225
#
# /usr/local/lib/python3.12/dist-packages/IPython/core/interactiveshell.py in run_cell_magic(self, magic_name, line, cell)
#    2471             with self.builtin_trap:
#    2472                 args = (magic_arg_s, cell)
# ...
